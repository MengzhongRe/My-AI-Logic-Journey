# %%
from datasets import load_dataset
data_files = "https://the-eye.eu/public/AI/pile_preliminary_components/PUBMED_title_abstracts_2019_baseline.jsonl.zst"

# %%
pubmed_dataset = load_dataset("monology/pile-uncopyrighted", data_files="val.jsonl.zst", split="train")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# val.jsonl.zst:   0%|          | 0.00/338M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pubmed_dataset = load_dataset("monology/pile-uncopyrighted", data_files="val.jsonl.zst", split="train")
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/load.py:1512, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1509     return builder_instance.as_streaming_dataset(split=split)
#    1511 # Download and prepare data
# -> 1512 builder_instance.download_and_prepare(
#    1513     download_config=download_config,
#    1514     download_mode=download_mode,
#    1515     verification_mode=verification_mode,
#    1516     num_proc=num_proc,
#    1517     storage_options=storage_options,
#    1518 )
#    1520 # Build dataset for splits
#    1521 keep_in_memory = (
#    1522     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    1523 )
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/builder.py:884, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, dl_manager, base_path, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     882 if num_proc is not None:
#     883     prepare_split_kwargs["num_proc"] = num_proc
# --> 884 self._download_and_prepare(
#     885     dl_manager=dl_manager,
#     886     verification_mode=verification_mode,
#     887     **prepare_split_kwargs,
#     888     **download_and_prepare_kwargs,
#     889 )
#     890 # Sync info
#     891 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/builder.py:925, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#     923 split_dict = SplitDict(dataset_name=self.dataset_name)
#     924 split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# --> 925 split_generators: list[SplitGenerator] = self._split_generators(dl_manager, **split_generators_kwargs)
#     927 # Checksums verification
#     928 if verification_mode == VerificationMode.ALL_CHECKS and dl_manager.record_checksums:
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/packaged_modules/json/json.py:79, in Json._split_generators(self, dl_manager)
#      77     raise ValueError(f"At least one data file must be specified, but got data_files={self.config.data_files}")
#      78 dl_manager.download_config.extract_on_the_fly = True
# ---> 79 data_files = dl_manager.download_and_extract(self.config.data_files)
#      80 splits = []
#      81 for split_name, files in data_files.items():
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/download/download_manager.py:326, in DownloadManager.download_and_extract(self, url_or_urls)
#     310 def download_and_extract(self, url_or_urls):
#     311     """Download and extract given `url_or_urls`.
#     312
#     313     Is roughly equivalent to:
#    (...)    324         extracted_path(s): `str`, extracted paths of given URL(s).
#     325     """
# --> 326     return self.extract(self.download(url_or_urls))
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/download/download_manager.py:159, in DownloadManager.download(self, url_or_urls)
#     157 start_time = datetime.now()
#     158 with stack_multiprocessing_download_progress_bars():
# --> 159     downloaded_path_or_paths = map_nested(
#     160         download_func,
#     161         url_or_urls,
#     162         map_tuple=True,
#     163         num_proc=download_config.num_proc,
#     164         desc="Downloading data files",
#     165         batched=True,
#     166         batch_size=-1,
#     167     )
#     168 duration = datetime.now() - start_time
#     169 logger.info(f"Downloading took {duration.total_seconds() // 60} min")
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/utils/py_utils.py:521, in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     518         batch_size = max(len(iterable) // num_proc + int(len(iterable) % num_proc > 0), 1)
#     519     iterable = list(iter_batched(iterable, batch_size))
#     520 mapped = [
# --> 521     _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     522     for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     523 ]
#     524 if batched:
#     525     mapped = [mapped_item for mapped_batch in mapped for mapped_item in mapped_batch]
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/utils/py_utils.py:408, in _single_map_nested(args)
#     404     return {
#     405         k: _single_map_nested((function, v, batched, batch_size, types, None, True, None)) for k, v in pbar
#     406     }
#     407 else:
# --> 408     mapped = [_single_map_nested((function, v, batched, batch_size, types, None, True, None)) for v in pbar]
#     409     if isinstance(data_struct, list):
#     410         return mapped
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/utils/py_utils.py:389, in _single_map_nested(args)
#     382         return function(data_struct)
#     383 if (
#     384     batched
#     385     and not isinstance(data_struct, dict)
#     386     and isinstance(data_struct, types)
#     387     and all(not isinstance(v, (dict, types)) for v in data_struct)
#     388 ):
# --> 389     return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#     391 # Reduce logging to keep things readable in multiprocessing with tqdm
#     392 if rank is not None and logging.get_verbosity() < logging.WARNING:
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/download/download_manager.py:220, in DownloadManager._download_batched(self, url_or_filenames, download_config)
#     206     return thread_map(
#     207         download_func,
#     208         url_or_filenames,
#    (...)    216         tqdm_class=tqdm,
#     217     )
#     218 else:
#     219     return [
# --> 220         self._download_single(url_or_filename, download_config=download_config)
#     221         for url_or_filename in url_or_filenames
#     222     ]
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/download/download_manager.py:229, in DownloadManager._download_single(self, url_or_filename, download_config)
#     226 if is_relative_path(url_or_filename):
#     227     # append the relative path to the base_path
#     228     url_or_filename = url_or_path_join(self._base_path, url_or_filename)
# --> 229 out = cached_path(url_or_filename, download_config=download_config)
#     230 out = tracked_str(out)
#     231 out.set_origin(url_or_filename)
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/datasets/utils/file_utils.py:188, in cached_path(url_or_filename, download_config, **download_kwargs)
#     178 resolved_path = huggingface_hub.HfFileSystem(
#     179     endpoint=config.HF_ENDPOINT, token=download_config.token
#     180 ).resolve_path(url_or_filename)
#     181 try:
#     182     output_path = huggingface_hub.HfApi(
#     183         endpoint=config.HF_ENDPOINT,
#     184         token=download_config.token,
#     185         library_name="datasets",
#     186         library_version=__version__,
#     187         user_agent=get_datasets_user_agent(download_config.user_agent),
# --> 188     ).hf_hub_download(
#     189         repo_id=resolved_path.repo_id,
#     190         repo_type=resolved_path.repo_type,
#     191         revision=resolved_path.revision,
#     192         filename=resolved_path.path_in_repo,
#     193         force_download=download_config.force_download,
#     194         proxies=download_config.proxies,
#     195     )
#     196 except (
#     197     huggingface_hub.utils.RepositoryNotFoundError,
#     198     huggingface_hub.utils.EntryNotFoundError,
#     199     huggingface_hub.utils.RevisionNotFoundError,
#     200     huggingface_hub.utils.GatedRepoError,
#     201 ) as e:
#     202     raise FileNotFoundError(str(e)) from e
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/huggingface_hub/hf_api.py:5467, in HfApi.hf_hub_download(self, repo_id, filename, subfolder, repo_type, revision, cache_dir, local_dir, force_download, proxies, etag_timeout, token, local_files_only, resume_download, force_filename, local_dir_use_symlinks)
#    5463 if token is None:
#    5464     # Cannot do `token = token or self.token` as token can be `False`.
#    5465     token = self.token
# -> 5467 return hf_hub_download(
#    5468     repo_id=repo_id,
#    5469     filename=filename,
#    5470     subfolder=subfolder,
#    5471     repo_type=repo_type,
#    5472     revision=revision,
#    5473     endpoint=self.endpoint,
#    5474     library_name=self.library_name,
#    5475     library_version=self.library_version,
#    5476     cache_dir=cache_dir,
#    5477     local_dir=local_dir,
#    5478     local_dir_use_symlinks=local_dir_use_symlinks,
#    5479     user_agent=self.user_agent,
#    5480     force_download=force_download,
#    5481     force_filename=force_filename,
#    5482     proxies=proxies,
#    5483     etag_timeout=etag_timeout,
#    5484     resume_download=resume_download,
#    5485     token=token,
#    5486     headers=self.headers,
#    5487     local_files_only=local_files_only,
#    5488 )
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)   1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/huggingface_hub/file_download.py:1168, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1165 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1167 with WeakFileLock(lock_path):
# -> 1168     _download_to_tmp_and_move(
#    1169         incomplete_path=Path(blob_path + ".incomplete"),
#    1170         destination_path=Path(blob_path),
#    1171         url_to_download=url_to_download,
#    1172         proxies=proxies,
#    1173         headers=headers,
#    1174         expected_size=expected_size,
#    1175         filename=filename,
#    1176         force_download=force_download,
#    1177         etag=etag,
#    1178         xet_file_data=xet_file_data,
#    1179     )
#    1180     if not os.path.exists(pointer_path):
#    1181         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/huggingface_hub/file_download.py:1735, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1728         if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#    1729             logger.warning(
#    1730                 "Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. "
#    1731                 "Falling back to regular HTTP download. "
#    1732                 "For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`"
#    1733             )
# -> 1735         http_get(
#    1736             url_to_download,
#    1737             f,
#    1738             proxies=proxies,
#    1739             resume_size=resume_size,
#    1740             headers=headers,
#    1741             expected_size=expected_size,
#    1742         )
#    1744 logger.info(f"Download complete. Moving file to {destination_path}")
#    1745 _chmod_and_move(incomplete_path, destination_path)
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/huggingface_hub/file_download.py:493, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     491 new_resume_size = resume_size
#     492 try:
# --> 493     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     494         if chunk:  # filter out keep-alive new chunks
#     495             progress.update(len(chunk))
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/urllib3/response.py:1253, in HTTPResponse.stream(self, amt, decode_content)
#    1247 else:
#    1248     while (
#    1249         not is_fp_closed(self._fp)
#    1250         or len(self._decoded_buffer) > 0
#    1251         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1252     ):
# -> 1253         data = self.read(amt=amt, decode_content=decode_content)
#    1255         if data:
#    1256             yield data
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/urllib3/response.py:1108, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1105     if len(self._decoded_buffer) >= amt:
#    1106         return self._decoded_buffer.get(amt)
# -> 1108 data = self._raw_read(amt)
#    1110 flush_decoder = amt is None or (amt != 0 and not data)
#    1112 if (
#    1113     not data
#    1114     and len(self._decoded_buffer) == 0
#    1115     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1116 ):
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/urllib3/response.py:1024, in HTTPResponse._raw_read(self, amt, read1)
#    1021 fp_closed = getattr(self._fp, "closed", False)
#    1023 with self._error_catcher():
# -> 1024     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1025     if amt is not None and amt != 0 and not data:
#    1026         # Platform-specific: Buggy versions of Python.
#    1027         # Close the connection when no data is returned
#    (...)   1032         # not properly close the connection in all cases. There is
#    1033         # no harm in redundantly calling close.
#    1034         self._fp.close()
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/site-packages/urllib3/response.py:1007, in HTTPResponse._fp_read(self, amt, read1)
#    1004     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1005 else:
#    1006     # StringIO doesn't like amt=None
# -> 1007     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/deep_learning/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
